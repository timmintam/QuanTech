# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ar1 = np.load('h3_full_200shots.npy')
ar2 = np.load('h3_full_200shots_no_div.npy')
ar3 = np.load('h3_full_10shots.npy')
ar4 = np.load('h3_diagonal_10shots.npy')
#ar5 = np.load('h3_diagonal_200shots_no_div.npy') invalid simulation
ar6 = np.load('h3_full_200shots_delta=8dt.npy')
ar7 = np.load('h3_full_50shots_delta=8dt.npy')
ar8 = np.load('h3_diagonal_50shots_delta=8dt.npy')
ar9 = np.load('h3_full_10shots_8dt.npy')
ar10 = np.load('h3_diagonal_10shots_delta=8dt.npy')

# %%
plt.title('Simulation of H3 dynamics for 60.0 fs')
plt.plot(ar1[0,:],ar1[1,:],label='200 shots, full')
plt.plot(ar1[0,:],ar2[1,:],label='200 shots, full, no div')
plt.plot(ar1[0,:],ar3[1,:],label='10 shots, full')
plt.plot(ar1[0,:],ar4[1,:],label='10 shots, diagonal')
#plt.plot(ar1[0,:],ar5[1,:],label='200 shots, diagonal, no div')


plt.legend()
plt.show()

# %%
plt.title('Simulation of H3 dynamics for 60.0 fs, $\delta=8dt$')
plt.plot(ar1[0,:],ar6[1,:],label='200 shots, full,delta=8dt')
plt.plot(ar1[0,:],ar7[1,:],label='50 shots, full,delta=8dt')
plt.plot(ar1[0,:],ar8[1,:],label='50 shots, diagonal,delta=8dt')
plt.plot(ar1[0,:],ar9[1,:],label='10 shots, full,delta=8dt')
plt.plot(ar1[0,:],ar10[1,:],label='10 shots, diagonal,delta=8dt')          
plt.legend()
plt.plot()
# Out:
# []
